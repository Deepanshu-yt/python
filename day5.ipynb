# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshu-yt/python/blob/main/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
  name = "dev"
  roll_no = 101
  def __init__(self,name,roll_no): # constructor | self -> this
    self.name = name
    self.roll_no = roll_no

s = Student("dev",101)
print(s.name)
print(s.roll_no)
# Out:
# dev
# 101

# %%
from typing import AsyncGenerator
class Student:
  def __init__(self,name,roll_no,age): # constructor | self -> this
    self.name = name
    self.roll_no = roll_no
    self.age = age

s = Student("dev",101,20)
print(s.name)
print(s.roll_no)
print(s.age)
# Out:
# dev
# 101
# 20

# %%
class Student:
  def __init__(this, name,roll_no,age): # constructor | self -> this
    this.name = name
    this.roll_no = roll_no
    this.age = age

# if you don't remember sequence

s=Student(name="dev",roll_no=101,age=20)
print(s.name)
print(s.roll_no)
print(s.age)
# Out:
# dev
# 101
# 20

# %%
class Student:
  def __init__(this, name,roll_no,age=None): # constructor | self -> this
    this.name = name
    this.roll_no = roll_no
    this.age = age


s = Student("dev",101)
print(s.name)
print(s.roll_no)
print(s.age)
# Out:
# dev
# 101
# None

# %%
class Student:
  def __init__(this,name='dev',roll_no=190,age=None): # default -> raj,123,none
    this.name = name
    this.roll_no = roll_no
    this.age = age

s = Student("deep",123)
print(s.name,s.roll_no,s.age)

s1 = Student("dop",123,20)
print(s1.name,s1.roll_no,s1.age)

#
s2 = Student()
print(s2.name,s2.roll_no,s2.age)
# Out:
# deep 123 None
# dop 123 20
# dev 190 None

# %%
class Student:
  def __init__(this,*args):
 #   print(type(args)) # type - tuple | immutable
 #  print(args) # tuple ('dev', 202, 30)
    this.data = args

s = Student("dev",101,20)
print(s.data[0], s.data[1], s.data[2])
# Out:
# dev 101 20

# %%
class Student:
  def __init__(self,*args):
    self.data = args
s = Student(["dev", "shiv", "deep"])
print(s.data[0][1])
# Out:
# shiv

# %%
# example
class Student:
  def __init__(self,*args):
    self.data = args


s = Student({"users":["vikas","ram","dev","neetu"]},{"address":{"home-town":"kukas","office":"jaipur"}})
# print(s.data[0]["users"]) # all users , kukas ,jaipur
# print(s.data[1]["address"]) # all users , kukas ,jaipur

#
for i in s.data[1]["address"].keys():
  # print(i)
  print(s.data[1]["address"][i])


for i in s.data[0]["users"]:
  print(i)
# Out:
# kukas
# jaipur
# vikas
# ram
# dev
# neetu

# %%
class Student:
  def __init__(self,name,roll_no):
    self.name = name
    self.roll_no = roll_no
  # get
  def getName(self):
    print(self.name)
  # update
  def updateName(self):
    self.name = "hello"
    print(self.name)
  # delete
  def deleteName(self):
    del self.name
    # print(self.name)
  # create
  def createName(self):
    self.full_name = "dev"
    print(self.full_name)

s = Student("nikhil",123)
s.createName()
# Out:
# dev
