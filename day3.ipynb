# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshu-yt/python/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("deepanshu")
# Out:
# deepansu
