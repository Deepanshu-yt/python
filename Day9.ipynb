# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepanshu-yt/python/blob/main/Day9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandas

# %%
import pandas as pd
l = [10,20,30,40]
df = pd.Series(l)
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
import pandas as pd
data = [['devendra',10],['nikhil',20],['raj',30],['hello',40]]
df = pd.DataFrame(data)
print(df)

# add cols name
df = pd.DataFrame(data,columns=['name','age'])
print(df)


# add indexing name
df = pd.DataFrame(data,index=['a','b','c','d'])
print(df)
# Out:
#           0   1
# 0  devendra  10
# 1    nikhil  20
# 2       raj  30
# 3     hello  40
#        name  age
# 0  devendra   10
# 1    nikhil   20
# 2       raj   30
# 3     hello   40
#           0   1
# a  devendra  10
# b    nikhil  20
# c       raj  30
# d     hello  40

# %%
#github csv
import pandas as pd
url = "https://raw.githubusercontent.com/rajendra0968jangid/Aws-ML-arya/main/file.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
#github csv
import pandas as pd
url = "https://raw.githubusercontent.com/Deepanshu-yt/python/main/FILE.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
#github csv
import pandas as pd
url = "https://raw.githubusercontent.com/Deepanshu-yt/python/main/file.xlsx"
df = pd.read_excel(url)
print(df)
# Out:
#        name gender
# 0    nikhil   male
# 1       raj   male
# 2  devendra   male
# 3     hello   male

# %%
#github csv
import pandas as pd
url = "https://raw.githubusercontent.com/Deepanshu-yt/python/main/data.json"
df = pd.read_json(url)
print(df)
# Out:
#        name  age
# 0    nikhil   10
# 1  devendra   20
# 2       raj   30
# 3     hello   40
